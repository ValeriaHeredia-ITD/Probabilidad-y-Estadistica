# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriaHeredia-ITD/Probabilidad-y-Estadistica/blob/main/Practica3_ValeriaHeredia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Probabilidad y Estadística**
# ## *Unidad 1.*
#
# *Práctica 3. Máximo, mínimo, rango y dispersión.*
#
# Facilitador: Dr. José Gabriel Rodriguez Rivas
#
# Alumna: Ángel Valeria Heredia Martínez

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1= []
for i in range(100):
  numero_aleatorio= round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [52.21, 53.43, 57.16, 63.74, 93.47, 80.42, 52.99, 70.66, 51.12, 75.19, 67.16, 55.31, 98.94, 75.23, 60.33, 97.97, 59.37, 80.37, 57.95, 90.98, 97.13, 94.16, 56.02, 84.3, 97.59, 93.38, 81.21, 98.27, 81.57, 75.07, 54.77, 86.71, 79.7, 87.35, 90.34, 81.67, 59.06, 88.94, 88.08, 57.74, 75.5, 98.99, 92.52, 83.01, 85.87, 81.09, 73.64, 70.16, 76.47, 91.64, 76.67, 77.5, 82.57, 93.51, 79.92, 53.62, 98.8, 75.34, 75.42, 52.2, 93.42, 69.1, 83.56, 85.87, 57.17, 76.07, 84.62, 75.15, 77.36, 51.12, 80.43, 82.75, 85.3, 78.13, 94.83, 67.79, 71.29, 67.52, 91.49, 59.58, 81.27, 98.64, 99.74, 72.49, 61.36, 64.15, 93.82, 52.76, 80.6, 63.75, 62.43, 99.35, 52.49, 88.68, 94.25, 74.31, 71.88, 56.1, 54.05, 74.44]

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio2= round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [57.28, 54.85, 54.58, 99.65, 73.5, 86.61, 52.89, 89.8, 68.9, 64.54, 73.72, 91.16, 65.36, 85.08, 71.32, 80.54, 94.84, 90.53, 61.82, 99.53, 85.89, 96.52, 61.64, 60.1, 86.46, 59.77, 74.63, 67.39, 85.12, 64.36, 54.87, 81.16, 67.0, 60.86, 72.89, 86.46, 60.5, 64.6, 97.06, 67.65, 84.53, 68.08, 64.16, 77.58, 55.63, 93.8, 79.8, 54.06, 99.72, 89.45, 65.17, 74.47, 66.99, 59.2, 69.36, 69.46, 64.62, 77.44, 59.45, 57.92, 73.84, 65.62, 92.19, 75.77, 84.39, 67.39, 91.34, 95.78, 68.83, 56.49, 69.84, 94.83, 61.0, 77.39, 58.71, 90.74, 57.51, 86.09, 75.44, 93.34, 71.27, 94.33, 87.72, 71.01, 52.85, 90.5, 50.34, 54.24, 92.91, 95.72, 60.58, 87.31, 84.13, 58.16, 82.57, 93.63, 78.45, 50.36, 81.11, 93.73]

# %% [markdown]
# # **Máximo, mínimo, rango**

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Estadistica descriptiva en la Fábrica 1\n", "Media= ",media1,
      "\n Mediana= ",mediana1, "Moda= ",moda1, "\n Máximo= ", maximo1, "\n Mínimo", minimo1,"\n Rango= ", rango1)
# Out:
# Estadistica descriptiva en la Fábrica 1
#  Media=  76.5061
#  Mediana=  77.43 Moda=  51.12
#  Máximo=  99.74
#  Mínimo 51.12
#  Rango=  48.62

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Estadistica descriptiva en la Fábrica 2\n", "Media= ",media2,
      "\n Mediana= ",mediana2, "Moda= ",moda2, "\n Máximo= ", maximo2, "\n Mínimo", minimo2,"\n Rango= ", rango2)
# Out:
# Estadistica descriptiva en la Fábrica 2
#  Media=  74.6977
#  Mediana=  73.61 Moda=  86.46
#  Máximo=  99.72
#  Mínimo 50.34
#  Rango=  49.379999999999995

# %% [markdown]
# ## **Dispersión de los datos**

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.647296361341558

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.244516708991123

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"Media={media1:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed",linewidth=2, label=f"Mediana={mediana1:.2f}")
plt.axvline(moda1, color="y", linestyle="dashed",linewidth=2, label=f"Moda={moda1:.2f}")
plt.axvline(media1- desviacion_estandar_fabrica1, color="black", linestyle="dashed", linewidth=2, label=f"Desviacion estandar={desviacion_estandar_fabrica1:.2f}")
plt.axvline(media1+ desviacion_estandar_fabrica1, color="black", linestyle="dashed", linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diaria de la Fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"Media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed",linewidth=2, label=f"Mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed",linewidth=2, label=f"Moda={moda2:.2f}")
plt.axvline(media2- desviacion_estandar_fabrica2, color="black", linestyle="dashed",
            linewidth=2, label=f"Desviacion estandar={desviacion_estandar_fabrica2:.2f}")
plt.axvline(media2+ desviacion_estandar_fabrica2, color="black", linestyle="dashed", linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Producción diaria de la Fábrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns
#La densidad fráfica es una forma de visualizar la distribución de datos en
# un intervalo o periodo de tiempo continuo.
#Se basa en un histograma que se usa el suavizado de kernel para trazar valores,
#lo que permite obtener distribuciones más suaves al reducir el ruido.
#Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot( x =fabrica1, kde = True, kde_kws = {"bw_adjust" : 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
