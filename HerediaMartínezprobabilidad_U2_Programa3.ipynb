# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriaHeredia-ITD/Probabilidad-y-Estadistica/blob/main/HerediaMart%C3%ADnezprobabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as mt
from itertools import permutations

# Número total de asistentes
n = 10

# Número de preguntas/asistentes a seleccionar
r = 4

# Calcular el número de permutaciones
Pr = mt.factorial(n) / mt.factorial(n - r)

print("Existen", Pr, "maneras de elegir 4 asistentes de un total de 10.")

# Generar las permutaciones
asistentes = ["Asistente " + str(i + 1) for i in range(n)]
permutaciones_asistentes = list(permutations(asistentes, r))

# Imprimir las permutaciones
print("Aquí están las permutaciones:")
for permutacion in permutaciones_asistentes:
    print(permutacion)
# Out:
# Existen 5040.0 maneras de elegir 4 asistentes de un total de 10.
# Aquí están las permutaciones:
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 4')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 5')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 6')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 7')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 8')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 9')
# ('Asistente 1', 'Asistente 2', 'Asistente 3', 'Asistente 10')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 3')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 5')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 6')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 7')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 8')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 9')
# ('Asistente 1', 'Asistente 2', 'Asistente 4', 'Asistente 10')
# ...
